# %%
#where to look and previous state

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mp # library to plot math functions

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
 #magic function: invokes internal function of jupyter; here it is for inlining plots for below graphs

# %%
x = np.linspace(0,5,11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x**2

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'ro')

# %%
plt.plot(x,y,'rp')

# %%
plt.plot(x,y,'r+')

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
# Out:
# Text(0.5,1,'graph')

# %%
plt.plot(x,y,'r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()

# %%
plt.plot(y,x,'b')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()
plt.plot(x,y,'r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()

# %%
plt.plot(y,x,'b')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')


plt.plot(x,y,'r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
plt.show()

# %%
plt.plot(y,x,'bo')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')


plt.plot(x,y,'r+')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('graph')
# Out:
# Text(0.5,1,'graph')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'r--')
plt.subplot(2,1,2)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()

# %%
axes = fig.add_axes([0.1,0.1,0.8,0.8])
# Out:
# /home/maneesh/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'b+')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('graph')

fig1 = plt.figure()
axes = fig1.add_axes([0.1,0.1,0.8,0.8])
axes.plot(y,x,'b+')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('graph')
fig.show()
fig1.show()
# Out:
# /home/maneesh/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.1,0.1])
axes.plot(x,y,'b+')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('graph')
# Out:
# Text(0.5,1,'graph')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.1,0.1])
axes2 = fig.add_axes([0.8,0.4,0.5,0.1])
axes.plot(x,y,'b+')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('graph')
# Out:
# Text(0.5,1,'graph')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y,'b+-')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('graph')
axes2.plot(y,x,'r+-')

# %%
fig, (a,b,c) = plt.subplots(1,3)
a.plot(x,y)
b.plot(x,y)
c.plot(x,y)

# %%
fig, z = plt.subplots(2,2)
z[0][0].plot(x,y,'b+-')
z[1][1].plot(x,y,'b+-')

# %%
z
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7d3a7d70f0>,
# ...
#       dtype=object)
