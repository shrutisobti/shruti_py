# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
s = pd.read_csv('Salaries.csv')

# %%
s
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
s.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
s['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
# 5         118602.00
# 6          92492.01
# 7         256576.96
# 8         176932.64
# 9         285262.00
# 10        194999.39
# 11         99722.00
# 12        294580.02
# 13        271329.03
# 14        174872.64
# 15        198778.01
# 16        268604.57
# 17        140546.87
# 18        168692.63
# 19        257510.59
# 20        257510.48
# 21        257510.44
# 22        140546.88
# 23        168692.63
# 24        140546.86
# 25        256470.41
# 26         92080.80
# 27        168692.59
# 28        261717.60
# 29        246225.60
#             ...
# 148624         0.00
# 148625         0.00
# 148626         0.00
# 148627         0.00
# 148628         0.00
# 148629         0.00
# 148630         0.00
# 148631         0.00
# 148632         0.00
# 148633         0.00
# 148634         0.00
# 148635         0.00
# 148636         0.00
# 148637         0.00
# ...

# %%
sum(s['BasePay'])# because of NAN values in dataset it is returning sum as NAN
# Out:
# nan

# %%
# In mean it is droping NAN values but in fill na with zero since count of number of rows is increased that is why there is difference in mean 
# but when we did same with drop na and taking shape of dataframe after droping nan values rows it is giving same answer :)

# %%
sum (s['BasePay'].dropna())/s['BasePay'].dropna().shape[0]
# Out:
# 66325.44884050643

# %%
sum (s['BasePay'].fillna(value = 0))/s.shape[0]
# Out:
# 66053.72928809702

# %%
s.shape[0]
# Out:
# 148654

# %%
s['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
s['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
x=s[s['EmployeeName']== 'JOSEPH DRISCOLL']

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
x['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
x['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
max (s['TotalPayBenefits'])
# Out:
# 567595.43

# %%
s[s['TotalPayBenefits']== max (s['TotalPayBenefits'])]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
s[s['TotalPayBenefits']== min (s['TotalPayBenefits'])]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
s['Year'].value_counts()
# Out:
# 2014    38123
# 2013    37606
# 2012    36766
# 2011    36159
# Name: Year, dtype: int64

# %%
s.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
s.nunique()['JobTitle']
# Out:
# 2159

# %%
s.nunique()
# Out:
# Id                  148654
# EmployeeName        110811
# JobTitle              2159
# BasePay             109489
# OvertimePay          65998
# OtherPay             83225
# Benefits             98465
# TotalPay            138486
# TotalPayBenefits    142098
# Year                     4
# Notes                    0
# Agency                   1
# Status                   0
# dtype: int64

# %%
s.nunique(dropna= False)
# Out:
# Id                  148654
# EmployeeName        110811
# JobTitle              2159
# BasePay             109490
# OvertimePay          65999
# OtherPay             83226
# Benefits             98466
# TotalPay            138486
# TotalPayBenefits    142098
# Year                     4
# Notes                    1
# Agency                   1
# Status                   1
# dtype: int64

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
s['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
s.head(0)
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
s[s['Year']== 2013].nunique()['JobTitle']
# Out:
# 1051

# %%
sum(s[s['Year']== 2013]['JobTitle'].value_counts()==1)
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
def countchief(strng):
    strng = strng.upper()
    c = 0
    l= strng.split(' ')
    for i in l:
        if i=='CHIEF':
            return True
    return False

# %%
s['JobTitle'].apply(countchief).value_counts()
# Out:
# False    148177
# True        477
# Name: JobTitle, dtype: int64

# %%
def countchief(strng):
    
    l= strng.split(' ')
    for i in l:
        if i=='CHIEF':
            return True
    for i in l:
        if i == 'Chief':
            return 2
    return 0

# %%
s['JobTitle'].apply(countchief).value_counts()
# Out:
# 0       148177
# 2          319
# True       158
# Name: JobTitle, dtype: int64

# %%
s['JobTitle'] = s['JobTitle'].apply(str.lower)

# %%
s.JobTitle.str.match('chief').value_counts()
# Out:
# False    148355
# True        299
# Name: JobTitle, dtype: int64

# %%
s['JobTitle'].str.contains(' chief').value_counts()
# Out:
# False    148326
# True        328
# Name: JobTitle, dtype: int64

# %%
s['JobTitle'].str.contains('chief ').value_counts()
# Out:
# False    148180
# True        474
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
s.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204878    -0.081505 -0.100403 -0.348957
# BasePay          -0.204878  1.000000     0.266740  0.285655  0.918028
# OvertimePay      -0.081505  0.266740     1.000000  0.316592  0.301207
# OtherPay         -0.100403  0.285655     0.316592  1.000000  0.233178
# Benefits         -0.348957  0.918028     0.301207  0.233178  1.000000
# TotalPay         -0.211478  0.954494     0.504859  0.470496  0.884097
# TotalPayBenefits -0.092190  0.946595     0.467981  0.422341  0.930140
# Year              0.968171  0.033751     0.027887 -0.002499 -0.043136
# Notes                  NaN       NaN          NaN       NaN       NaN
# Status                 NaN       NaN          NaN       NaN       NaN
#
#                   TotalPay  TotalPayBenefits      Year  Notes  Status
# Id               -0.211478         -0.092190  0.968171    NaN     NaN
# ...

# %%
df= s[['TotalPayBenefits']]

# %%
s['tit_len']= s['JobTitle'].apply(len)

# %%
s
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %%
df.corr()
# Out:
#                   TotalPayBenefits   tit_len
# TotalPayBenefits          1.000000 -0.036878
# tit_len                  -0.036878  1.000000

# %%
s[['TotalPayBenefits','tit_len']].corr()
# Out:
#                   TotalPayBenefits   tit_len
# TotalPayBenefits          1.000000 -0.036878
# tit_len                  -0.036878  1.000000

# %% [markdown]
# # Great Job!
